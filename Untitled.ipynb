# %%
import pymysql
import csv
import pandas as pd

# %%
db = pymysql.connect(
    host = 'localhost',
    port = 3306,
    user = 'root',
    passwd = '1234',
    db = 'sosanggongin',
    charset = 'utf8'
)
cursor = db.cursor()

# %%
f = open('#핫플.csv','r')
csvReader = csv.reader(f)

for row in csvReader:
    키워드 = row[0]
    월간검색량 = row[1]
    누적발행량 = row[2]
    철자유사도 = row[3]
    
    print(키워드)
    print(월간검색량)
    print(누적발행량)
    print(철자유사도)
# Out:
# ﻿"키워드"
# 월간 검색량 (Total)
# 블로그 누적 발행량
# 철자 유사도
# 핫플공구
# 200
# 4278
# 3
# 핫플 뜻
# 260
# 42586
# 3
# 김포 핫플
# 980
# 12487
# 3
# 제주 핫플
# 5110
# 118705
# 3
# 대구 핫플
# 5390
# 165088
# 3
# 성수 핫플
# 5630
# 40252
# 3
# 제주도핫플
# 5700
# 103373
# 2
# 부산 핫플
# 7720
# 178195
# 3
# 제주 핫플레이스
# 8140
# 91950
# 2
# 제주도 핫플레이스
# 8180
# 83143
# 2
# 성수동 핫플
# 9760
# 36314
# 2
# 서울 핫플
# 13620
# 225674
# 3
# 서울 핫플레이스
# 15670
# 223659
# 2
# 경기도가볼만한곳
# 187700
# 61656
# 1
# 통영 가볼만한곳
# 187800
# 5057808
# 1
# 서울가볼만한곳
# 198500
# 7061178
# 1
# 부산가볼만한곳
# 280100
# 5845868
# 1
# 제주도 날씨
# 832200
# 1526382
# 1
# 어버이날
# 841900
# 1439960
# 1
# 제주 날씨
# 1307400
# 1497119
# 1
